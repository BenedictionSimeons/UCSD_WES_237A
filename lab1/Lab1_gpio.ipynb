# %%
# Interacting with GPIO from MicroBlaze
from pynq.overlays.base import BaseOverlay
import time
from datetime import datetime
base = BaseOverlay("base.bit")

# %%
# %%microblaze base.PMODB
#
# #include "gpio.h"
# #include "pyprintf.h"
#
# #//Function to turn on/off a selected pin of PMODB
# void write_gpio(unsigned int pin, unsigned int val){
#     if (val > 1){
#         pyprintf("pin value must be 0 or 1");
#     }
#     gpio pin_out = gpio_open(pin);
#     gpio_set_direction(pin_out, GPIO_OUT);
#     gpio_write(pin_out, val);
# }
#
# #//Function to read the value of a selected pin of PMODB
# unsigned int read_gpio(unsigned int pin){
#     gpio pin_in = gpio_open(pin);
#     gpio_set_direction(pin_in, GPIO_IN);
#     return gpio_read(pin_in);
# }

# %%
write_gpio(0, 2)
read_gpio(1)
# Multi-tasking with MicroBlaze 
base = BaseOverlay("base.bit")
# Out:
# pin value must be 0 or 1

# %%
# %%microblaze base.PMODA
#
# #include "gpio.h"
# #include "pyprintf.h"
#
# //Function to turn on/off a selected pin of PMODA
# void write_gpio(unsigned int pin, unsigned int val){
#     if (val > 1){
#         pyprintf("pin value must be 0 or 1");
#     }
#     gpio pin_out = gpio_open(pin);
#     gpio_set_direction(pin_out, GPIO_OUT);
#     gpio_write(pin_out, val);
# }
#
# //Function to read the value of a selected pin of PMODA
# unsigned int read_gpio(unsigned int pin){
#     gpio pin_in = gpio_open(pin);
#     gpio_set_direction(pin_in, GPIO_IN);
#     return gpio_read(pin_in);
# }
#
# //Multitasking the microblaze for a simple function
# int add(int a, int b){
#     return a + b;
# }

# %%
val = 1
write_gpio(1, val)
out = read_gpio(1)

add(2, 30)

# Lab work
# Use the code from the second cell as a template and write a code 
# to use two pins (0 and 1) for send and two pins (2 and 3) for receive. 
# You should be able to send 2bits (0~3) over GPIO. You'll need to hardwire from the send pins to the receive pins.

# %%
write_gpio(0, 1)

write_gpio(1, 1)

write_gpio(2, 0)

write_gpio(3, 0)

out_2 = read_gpio(7)
out_3 = read_gpio(6)

print(out_2)
print(out_3)
# Out:
# 1
# 0
